# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
iris=pd.read_csv('iris.csv')

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
sns.distplot(iris['sepal.width'])

# %%
sns.boxplot(x='variety',y='petal.length',data=iris)

# %%
sns.jointplot(x='sepal.length',y='sepal.width',data=iris,size=5)
# Out:
# C:\Users\Hari\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
ax=sns.stripplot(x='variety',y='sepal.length',data=iris,jitter=True,edgecolor='gray')

# %%
sns.violinplot(x='variety',y='sepal.length',data=iris,size=6)
